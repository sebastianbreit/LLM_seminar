# %%
import pandas as pd
import numpy as np
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, GPT2LMHeadModel, GPT2Tokenizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/requests/compat.py:11
#      10 try:
# ---> 11     import chardet
#      12 except ImportError:
#
# ModuleNotFoundError: No module named 'chardet'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, GPT2LMHeadModel, GPT2Tokenizer
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/transformers/__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
# ...

# %% [markdown]
# ## Other models
# - Alpacka/LLama
# - ?
